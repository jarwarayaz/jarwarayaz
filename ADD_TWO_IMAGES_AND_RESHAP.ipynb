# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b346b89d-41e8-449e-9029-d48875f02fae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b346b89d-41e8-449e-9029-d48875f02fae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Butterfly.jpg to Butterfly.jpg

# %%
# !ls
# Out:
# Butterfly.jpg  sample_data

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread("Butterfly.jpg")
img_cvt=cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.grid(None)
plt.show()

# %%
print(img1.shape)
# Out:
# (225, 225, 3)

# %%
IMG_SIZE1 = 300
IMG_SIZE2 = 400
smallimg1 = cv2.resize(img1,(IMG_SIZE1,IMG_SIZE2))
plt.imshow(smallimg1,cmap="gray")
plt.grid(None)

# %%
print(smallimg1.shape)
# Out:
# (400, 300, 3)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e3704199-30bd-4331-9762-8e525bc881de" name="files[]" multiple disabled />
#      <output id="result-e3704199-30bd-4331-9762-8e525bc881de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving butterfly_GT.bmp to butterfly_GT.bmp

# %%
img2 = cv2.imread("butterfly_GT.bmp")
img_cvt=cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.grid(None)
plt.show()

# %%
print(img2.shape)
# Out:
# (256, 256, 3)

# %%
IMG_SIZE = 500
smallimg2 = cv2.resize(img_cvt,(IMG_SIZE,IMG_SIZE))
plt.imshow(smallimg2,cmap="gray")
plt.grid(None)

# %%
print(smallimg2.shape)
# Out:
# (500, 500, 3)

# %%
add = smallimg1 + smallimg2 
plt.imshow(add,cmap="gray")
plt.grid(None)
